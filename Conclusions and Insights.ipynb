# %% [markdown]
# # Conclusions and Insights
#
# Let us look at what we have and can learn from the project.
#
# ![Insights-hero.png](attachment:Insights-hero.png)
#
# <br>
# <br>

# %% [markdown]
# ## Context
#
#
# The data set includes information about:
#
#      Customers who left within the last month – the column is called Churn.
#
#      Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device             protection, tech support, and streaming TV and movies.
#
#      Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly               charges, and total charges.
#
#      Demographic info about customers – gender, age range, and if they have partners and dependents.

# %% [markdown]
# ## Ranking the Features According to thier Importance
# <br>
# <br>
#
# ![__results___139_0.png](attachment:__results___139_0.png)
#
# <br>
#
# The feature importance are from the [Catboost’s predictions.](https://www.kaggle.com/jonaspalucibarbosa/telco-customer-churn-eda-predictions-shap?scriptVersionId=67707471&cellId=139)

# %% [markdown]
# <br>
#
# ![features.png](attachment:features.png)
#
# <br>
#
# <br>
#
# ![features%20all.png](attachment:features%20all.png)
#
# <br>

# %% [markdown]
# ## Insights
#
# #### Factors Causing of High Churn
# - Month to Month Contracts
# - No online security
# - No Tech support
# - First year of subscription
# - Fibre Optics Internet
#
#
# #### Factors Against High Churn
# - Long term contracts
# - Subscriptions without internet service
# - The customers engaged for 5+ years
#
# <br>
# <br>
#
# ## Features
#
# - Gender
#     - Gender has almost a 50/50 split and negligible difference in churn percentages.
# - Senior Citizens
#     - Senior citizens have close to double the rate of churn; however, they make up only 1/6th of the total customer population
# - Phone Service
#     - Rate of churn is similar regardless whether a customer has phone service or not.
# - Tenure
#     - Long time customers are less likely to leave the company.
# - TotalCharges
#     - More paying customers are more likely to leave the company.
# - Internet Service-Fiber optic
#     - People having Fiber optic are more likely to leave.
# - OnlineSecurity
#     - People having this product are more loyal.
# - People using PaperlessBilling and Electronic Payment services are more likely to leave.

# %% [markdown]
# <br>
#
# ## Confusion Matrix
#
# Another useful tool to assess the performance of a model is the confusion matrix. The confusion matrix below shows how many predictions were correct and how many were incorrect.
#
# ![Matrix.png](attachment:Matrix.png)
#
# ![confusion.jpg](attachment:confusion.jpg)
#
# <br>
#
# - True negatives
#     - In the upper left are the 'true negatives', i.e. the model predicted 'no churn' and the customer actually didn't churn. (512)
#
# - False negatives
#     - In the lower left are the 'false negatives', i.e. the model predicted 'no churn', but the customer actually churned. (22)
#
# - True positives
#     - In the lower right are the 'true positives', i.e. the model predicted 'churn' and the customer actually churned. (596)
#
# - False positives
#     - In the upper right are the 'false positives', i.e. the model predicted 'churn', but the customer actually didn't churn. (33)

# %% [markdown]
# <br>
# <br>
#
# Simply looking at accuracy might not be sufficient to correctly assess a model's performance. Therefore, we calculate additional metrics called precision and recall.
#
# #### Precision:
#     - divide TP by the sum of all positive predictions, i.e. TP plus FP - in different words, how many customers did we correctly classify as churners in relation to how many customers we correctly classified overall
#
#     precision = TP / (TP + FP) = 596 / ( 596 + 33) = 0.94
#
#
# ####  Recall:
#     - divide TP by the sum of correct positive predictions and false negative predictions, i.e. TP plus FN - in other words, how many customers did we classify as churners in relation to how many customers acctually churned
#
#     recall = TP / (TP + FN) = 596 / (596 + 22) = 0.96
# <br>
#
# To jointly assess precision and recall we can calculate the f1-score.
#
# #### F1-score
#     - f1-score = 2 (precision recall) / (precision + recall) = 2 (0.94 0.96) / (0.94 + 0.96) = 0.95

# %% [markdown]
# <br>
#
# ## Final Insights
#
#
# - Customers with phone services are less likely to churn
# - Customers with internet services are more likely to churn
# - Customers with a longer relationship with the company are less likely to churn
# - Customers monthly contract are more likely to churn
# - Customers with paperless billing are more likely to churn
# - Customers with automatic payment methods are less likely to churn

# %% [markdown]
# <br>
#
# ## Follow up Questions which are Out of Scope of this Project
# ![Untitled_Artwork-8-1024x429.png](attachment:Untitled_Artwork-8-1024x429.png)
# <br>
#
#     - What is the Financial Impact of Churning? (What are the costs of churn?)
#
#     - Why do customers churn? (What are the drivers of churn?)
#
#     - What anti-churn tools are there?
#
#     - What are the competitors offering to attract customers?
#
#     - Are you selling to your ideal customer profile?
#
#     - What were the motive for customers to churn or discontinue?
#
#     - Why did the customer subscribe in the first place and what they are expecting?
#    <br>

# %% [markdown]
# <br>
#
# ## Quicklinks
#
# - [IBM Business Analytics Community](https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113) and [Kaggle.](https://www.kaggle.com/blastchar/telco-customer-churn)
# <br>
#
# - [Github Repository](https://github.com/prathishpratt/Customer-Churn)
# <br>
#
# - [Kaggle Profile](https://www.kaggle.com/prathishmurugan)
# <br>
#
# - [LinkedIn Profile](https://www.linkedin.com/in/prathish-murugan-147369193/)
# <br>

# %% [markdown]
# ![end.jpg](attachment:end.jpg)
